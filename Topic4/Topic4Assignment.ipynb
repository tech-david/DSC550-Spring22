# %%
# !pip install neurolab
import numpy as np
import matplotlib.pyplot as plt
import neurolab as nl

# hard limit instantiation
hardlim = nl.trans.HardLim()
# weights for graph a
w_a = np.array([-2, 1])
# bias for graph 1
b_a = 0
# a = 1
p_a_1 = np.array([-2,2])
# a = 0
p_a_0 = np.array([2,2])
# new point
p_a_rand = np.array([-1,1])

# calculate n for every point
n_a_1 = np.sum(np.multiply(p_a_1, w_a))+b_a
n_a_0 = np.sum(np.multiply(p_a_0, w_a))+b_a
n_a_rand = np.sum(np.multiply(p_a_rand, w_a)) + b_a

# decisioning
a_1 = hardlim(n_a_1)
a_0 = hardlim(n_a_0)
a_rand = hardlim(n_a_rand)

#results
print("input:%s --> target:%s" % (p_a_1, a_1))
print("input:%s --> target:%s" % (p_a_0, a_0))
print("input:%s --> target:%s" % (p_a_rand, a_rand))
# Out:
# ...
# input:[-2  2] --> target:1.0
# input:[2 2] --> target:0.0
# input:[-1  1] --> target:1.0

# %%
# Same format as first block but for graph b
hardlim = nl.trans.HardLim()

w_b = np.array([0, -2])
b_b = -1

p_b_1 = np.array([0,-2])
p_b_0 = np.array([0,2])
p_b_rand = np.array([1,-2])

n_b_1 = np.sum(np.multiply(p_b_1, w_b))+b_b
n_b_0 = np.sum(np.multiply(p_b_0, w_b))+b_b
n_b_rand = np.sum(np.multiply(p_b_rand, w_b)) + b_b

b_1 = hardlim(n_b_1)
b_0 = hardlim(n_b_0)
b_rand = hardlim(n_b_rand)
print("input:%s --> target:%s" % (p_b_1, b_1))
print("input:%s --> target:%s" % (p_b_0, b_0))
print("input:%s --> target:%s" % (p_b_rand, b_rand))
# Out:
# input:[ 0 -2] --> target:1.0
# input:[0 2] --> target:0.0
# input:[ 1 -2] --> target:1.0

# %%
# Same format as first block but for graph c
hardlim = nl.trans.HardLim()

w_c = np.array([1,-1])
b_c = 3

p_c_1 = np.array([2,0])
p_c_0 = np.array([-2,2])
p_c_rand = np.array([0,-1])

n_c_1 = np.sum(np.multiply(p_c_1, w_c))+b_c
n_c_0 = np.sum(np.multiply(p_c_0, w_c))+b_c
n_c_rand = np.sum(np.multiply(p_c_rand, w_c)) + b_c

c_1 = hardlim(n_c_1)
c_0 = hardlim(n_c_0)
c_rand = hardlim(n_c_rand)
print("input:%s --> target:%s" % (p_c_1, c_1))
print("input:%s --> target:%s" % (p_c_0, c_0))
print("input:%s --> target:%s" % (p_c_rand, c_rand))
# Out:
# input:[2 0] --> target:1.0
# input:[-2  2] --> target:0.0
# input:[ 0 -1] --> target:1.0
